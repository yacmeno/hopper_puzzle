# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
"""
data looks like gps coordinates... https://en.wikipedia.org/wiki/Decimal_degrees
maybe with some kind of scaling/manipulation
"""
data = pd.read_csv('puzzle.csv', header=None)

# %%
data.describe()
# Out:
#                  0            1
# count  1024.000000  1024.000000
# mean      0.504729    -0.388165
# std       0.355107     1.499346
# min      -0.925070    -2.837888
# 25%       0.389721    -1.559228
# 50%       0.591392    -1.129903
# 75%       0.746583     0.578621
# max       1.195399     3.096964

# %%
data.plot(kind='kde')
# y column with much more variance than x
# they don't follow the same distribution

# %%
data.duplicated().value_counts()
# around 112 duplicated values (mostly in the first rows it seems)
# 912 not duplicated

# %%
#data.plot(kind='scatter', x=1, y=0) #doesnt look like a world map
data.plot(kind='scatter', x=1, y=0) # looks like a world map

# North America and Europe have much more data points
# Maybe it's a representation of Hopper users' locations
# More users from english speaking countries+richer countries (more people can afford traveling)

# %%
#let's see where the duplicates are
dupl_series = data.duplicated(keep=False)
data_nodup = data[~dupl_series]
ax = data.plot(kind='scatter', x=1, y=0, color='Red', label='original', alpha=0.5)
#data_nodup.plot(kind='scatter', x=1, y=0, color='Black', label='no_dupl', alpha=0.5, ax=ax)
data[dupl_series].plot(kind='scatter', x=1, y=0, color='DarkGreen', label='duplicates', ax=ax)

# not sure what to think of this ¯\_(ツ)_/¯
# Doubt it's Hopper users that live in the same building!
